# %% [markdown]
# Built in Functions

# %% [markdown]
# To execute any cell :-
#
# 1. ctrl+enter
#
# 2. shift+enter

# %%
#code cell
#comment - are not going to get executed, they simply increase the readblity

# %%
a='India'

# %%
print(a)
# Out:
# India

# %%
type(a)
# Out:
# str

# %%
b=['India','China','USA',45,50,55,1.0,2.0,3.0]

# %%
print(b)
# Out:
# ['India', 'China', 'USA', 45, 50, 55, 1.0, 2.0, 3.0]

# %%
type(b)
# Out:
# list

# %%
c="-4.5"

# %%
print(c)
# Out:
# -4.5

# %%
type(c)
# Out:
# str

# %%
d='Macbook'

# %%
print(d)
# Out:
# Macbook

# %%
type(d)
# Out:
# str

# %%
print(a)
# Out:
# India

# %%
e='4.5'

# %%
print(e)
# Out:
# 4.5

# %%
name=input('Enter your name')
# Out:
# Enter your name45862

# %%
print(name)
# Out:
# 45862

# %%
type(name)
# Out:
# str

# %% [markdown]
# TypeCasting

# %%
otp=int(input("enter your 4 digit otp"))
# Out:
# enter your 4 digit otp4862

# %%
print(otp)
# Out:
# 4862

# %%
type(otp)
# Out:
# int

# %%
temp=float(input("Enter temp of your city"))
# Out:
# Enter temp of your city41

# %%
print(temp)
# Out:
# 41.0

# %%
type(temp)
# Out:
# float

# %% [markdown]
# Operations on Strings and Lists
#
# 1. Concatination
#
# 2. Indexing
#
# 3. Slicing

# %%
#concatination in strings
a='Indian'
b='Ocean'

print(a+b)
# Out:
# IndianOcean

# %%
type(a+b)
# Out:
# str

# %%
print(a+' '+b)
# Out:
# Indian Ocean

# %%
#concatination in lists
l1=[3,4,5,6]
l2=[1,2,3,4]
l3=['Mango','Banana','Grapes']

# %%
print(l1+l2+l3)
# Out:
# [3, 4, 5, 6, 1, 2, 3, 4, 'Mango', 'Banana', 'Grapes']

# %%
print(l3+l2+l1)
# Out:
# ['Mango', 'Banana', 'Grapes', 1, 2, 3, 4, 3, 4, 5, 6]

# %%
name=str(input("enter your name"))

a='Hi'
b='Good morning'
c='How are you?'

print(a+' '+name+' '+b+' '+c)
# Out:
# enter your nameAashutosh
# Hi Aashutosh Good morning How are you?

# %%
#indexing in strings
a='Mobile'

# %%
a[0]
# Out:
# 'M'

# %%
a[-6]
# Out:
# 'M'

# %%
a[2]
# Out:
# 'b'

# %%
a[-4]
# Out:
# 'b'

# %%
#indexing in lists
l1=['Mango','China','Apple','Maldives','Pakistan',45,80,35]

# %%
l1[3]
# Out:
# 'Maldives'

# %%
l1[-5]
# Out:
# 'Maldives'

# %%
#slicing
q='United Nations'

# %%
q[0:6]
# Out:
# 'United'

# %%
q[7:14]
# Out:
# 'Nations'

# %%
q[7:]
# Out:
# 'Nations'

# %%
q[-14:-8]
# Out:
# 'United'

# %%
q[-7:]
# Out:
# 'Nations'

# %%
x='haseena'

# %%
x[-4:-2]
# Out:
# 'ee'

# %%
a='United States'

# %%
a[-9:]
# Out:
# 'ed States'
