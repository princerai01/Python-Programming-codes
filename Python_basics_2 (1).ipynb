# %% [markdown]
# Nested List

# %%
l1=[[1,2,3,4],['India','USA','China'],['Mango','Grapes']]

# %%
#Mango
l1[2][0]
# Out:
# 'Mango'

# %%
#USA, China
l1[1][1:]
# Out:
# ['USA', 'China']

# %%
#Mango, Grapes
l1[2][:]
# Out:
# ['Mango', 'Grapes']

# %%
print(l1[1][1:]+l1[2][:])
# Out:
# ['USA', 'China', 'Mango', 'Grapes']

# %% [markdown]
# Built in Functions wrt Lists

# %%
l1=['Machine Learning','Python','Tableau','Statistics']

# %%
l1.append('PowerBI') #will add the element at the end of the list

# %%
print(l1)
# Out:
# ['Machine Learning', 'Python', 'Tableau', 'Statistics', 'PowerBI']

# %%
l1.insert(2,'Deep Learning') #will add the element at the desired index location

# %%
print(l1)
# Out:
# ['Machine Learning', 'Python', 'Deep Learning', 'Tableau', 'Statistics', 'PowerBI']

# %%
l1.extend(['Calculus','Probability','NLP']) #will add the elements at the end of the list

# %%
print(l1)
# Out:
# ['Machine Learning', 'Python', 'Deep Learning', 'Tableau', 'Statistics', 'PowerBI', 'Calculus', 'Probability', 'NLP']

# %%
l1.remove('Calculus') #will delete the element from the list

# %%
print(l1)
# Out:
# ['Machine Learning', 'Python', 'Deep Learning', 'Tableau', 'Statistics', 'PowerBI', 'Probability', 'NLP']

# %%
l1.remove('Python')

# %%
l1.remove('Tableau')

# %%
print(l1)
# Out:
# ['Machine Learning', 'Deep Learning', 'Statistics', 'PowerBI', 'Probability', 'NLP']

# %%
l1.remove(['Deep Learning', 'Statistics', 'PowerBI'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-7109537503b3> in <cell line: 1>()
# ----> 1 l1.remove(['Deep Learning', 'Statistics', 'PowerBI'])
#
# ValueError: list.remove(x): x not in list

# %%
print(l1)
# Out:
# ['Machine Learning', 'Deep Learning', 'Statistics', 'PowerBI', 'Probability', 'NLP']

# %%
l1.insert(1,'PowerBI')

# %%
print(l1)
# Out:
# ['Machine Learning', 'PowerBI', 'Deep Learning', 'Statistics', 'PowerBI', 'Probability', 'NLP']

# %%
l1.remove('PowerBI') #will delete the first occurance of the element from the list

# %%
print(l1)
# Out:
# ['Machine Learning', 'Deep Learning', 'Statistics', 'PowerBI', 'Probability', 'NLP']

# %%
len(l1)
# Out:
# 6

# %%
l1.count('NLP')
# Out:
# 1

# %%
l1.pop(2) #will delete the element from the given index position
# Out:
# 'Statistics'

# %%
print(l1)
# Out:
# ['Machine Learning', 'Deep Learning', 'PowerBI', 'Probability', 'NLP']

# %%
l2=[2,3,9,4,8,3,7,2,7,2,3,9,4,5,9,8,2,5,7]

# %%
sum(l2) #will add all the elements present inside the list
# Out:
# 99

# %%
max(l2) #will fetch the largest element from the list
# Out:
# 9

# %%
min(l2) #will fetch the smallest element from the list
# Out:
# 2

# %%
len(l2) #will count the total number of elements in the list
# Out:
# 19

# %%
l2.count(3) #will give the frequency of any particular element
# Out:
# 3

# %%
l2.count(2)
# Out:
# 4

# %%
l2.count(5)
# Out:
# 2

# %% [markdown]
# Mathematical Operators

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=25
b=20
c=a-b
print(c)
# Out:
# 5

# %%
a=5
b=8
c=a*b
print(c)
# Out:
# 40

# %%
a=10
b=3
c=a/b #float division
print(c)
# Out:
# 3.3333333333333335

# %%
a=10
b=3
c=a//b #integer division
print(c)
# Out:
# 3

# %%
a=2
b=25
print(2**25) #exponents
# Out:
# 33554432

# %%
print(a**b) #exponents
# Out:
# 33554432

# %%
a=10
b=2
c=a%b #modulo - for fetching the remainder of division op.
print(c)
# Out:
# 0

# %%
a=10
b=3
c=a%b
print(c) #modulo - for fetching the remainder of division op.
# Out:
# 1

# %% [markdown]
# Data Structures
#
# 1. Dictionaries
#
# 2. Tuples
#
# 3. Sets

# %% [markdown]
# Dictionaries

# %%
memo={'ice cream':200,'chips':40,'notebook':90,'chocolates':500}

# %%
type(memo)
# Out:
# dict

# %%
print(memo)
# Out:
# {'ice cream': 200, 'chips': 40, 'notebook': 90, 'chocolates': 500}

# %%
#in order to fetch the value we use name of key instead of index no.
memo['chips']
# Out:
# 40

# %%
memo['chocolates']
# Out:
# 500

# %%
#adding new key value pair to the dict
memo['pens']=100

# %%
print(memo)
# Out:
# {'ice cream': 200, 'chips': 40, 'notebook': 90, 'chocolates': 500, 'pens': 100}

# %%
#modifying values in dict
memo['chips']=80

# %%
print(memo)
# Out:
# {'ice cream': 200, 'chips': 80, 'notebook': 90, 'chocolates': 500, 'pens': 100}

# %%
del memo['ice cream']

# %%
print(memo)
# Out:
# {'chips': 80, 'notebook': 90, 'chocolates': 500, 'pens': 100}

# %% [markdown]
# Q. Create a dictionary 'info' with keys - 'name','age','salary', values - 'Bob', 28, 40000
#
# Q. Modify the salary to 35000
#
# Q. Add a new key value pair, key - 'city', value - 'Texas'
#
# Q. Delete the age key value pair and finally dispay the dictionary

# %%
info={'name':'Bob','age':28,'salary':40000}

# %%
info['salary']=35000

# %%
info['city']='Texas'

# %%
del info['age']

# %%
print(info)
# Out:
# {'name': 'Bob', 'salary': 35000, 'city': 'Texas'}

# %% [markdown]
# Tuples

# %%
t=('India','Pakistan',35,30,40.0,-20.5)

# %%
type(t)
# Out:
# tuple

# %%
print(t)
# Out:
# ('India', 'Pakistan', 35, 30, 40.0, -20.5)

# %%
t[1]
# Out:
# 'Pakistan'

# %%
t[3]
# Out:
# 30

# %%
t[1:4]
# Out:
# ('Pakistan', 35, 30)

# %%
t[0]='USA'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-3cde9a4f06d1> in <cell line: 1>()
# ----> 1 t[0]='USA'
#
# TypeError: 'tuple' object does not support item assignment
